# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import linear_model
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
# %matplotlib inline
sns.set()

# %%
# %%capture
from tqdm import tqdm_notebook as tqdm
tqdm().pandas()

# %%
file_path = "nyse_data/"

# %%
prices_adj = pd.read_csv(file_path + "prices-split-adjusted.csv")
fundamentals = pd.read_csv(file_path + "fundamentals.csv")
prices = pd.read_csv(file_path + "prices.csv")
securities = pd.read_csv(file_path + "securities.csv")

# %%
AAPL = prices_adj[prices_adj['symbol'] == 'AAPL']

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=AAPL.date, y=AAPL.close, name="AAPL close",
                         line_color='deepskyblue'))

fig.update_layout(title_text='Time Series with Rangeslider',
                  xaxis_rangeslider_visible=True)
fig.show()
# Out:
# <div>
#
#
#             <div id="a91af5f6-4444-46c3-879f-b2818e30a010" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a91af5f6-4444-46c3-879f-b2818e30a010")) {
#                     Plotly.newPlot(
#                         'a91af5f6-4444-46c3-879f-b2818e30a010',
# ...
